# %%
import pandas as pd
import os
from pathlib import Path

# %%
home = Path.cwd()
print(home)
# Out:
# /Users/jbrant/Desktop/DevOps/Python/lessons/10-pandas-eda-2/code

# %%
print(home.parent)
# Out:
# /Users/jbrant/Desktop/DevOps/Python/lessons/10-pandas-eda-2

# %%
hivdeaths=pd.read_csv("../../../projects/hiv-statistics/resources/hiv_deaths.csv", encoding='latin-1')

# %%
hivdeaths.columns
# Out:
# Index(['GHO (CODE)', 'GHO (DISPLAY)', 'GHO (URL)', 'PUBLISHSTATE (CODE)',
#        'PUBLISHSTATE (DISPLAY)', 'PUBLISHSTATE (URL)', 'YEAR (CODE)',
#        'YEAR (DISPLAY)', 'YEAR (URL)', 'REGION (CODE)', 'REGION (DISPLAY)',
#        'REGION (URL)', 'COUNTRY (CODE)', 'COUNTRY (DISPLAY)', 'COUNTRY (URL)',
#        'Display Value', 'Numeric', 'Low', 'High', 'StdErr', 'StdDev',
#        'Comments'],
#       dtype='object')

# %%
hivdeaths.drop("GHO (CODE)", axis=1)
# Out:
#                         GHO (DISPLAY)  \
# 0    Number of deaths due to HIV/AIDS
# 1    Number of deaths due to HIV/AIDS
# 2    Number of deaths due to HIV/AIDS
# 3    Number of deaths due to HIV/AIDS
# 4    Number of deaths due to HIV/AIDS
# 5    Number of deaths due to HIV/AIDS
# 6    Number of deaths due to HIV/AIDS
# 7    Number of deaths due to HIV/AIDS
# 8    Number of deaths due to HIV/AIDS
# 9    Number of deaths due to HIV/AIDS
# 10   Number of deaths due to HIV/AIDS
# 11   Number of deaths due to HIV/AIDS
# 12   Number of deaths due to HIV/AIDS
# 13   Number of deaths due to HIV/AIDS
# 14   Number of deaths due to HIV/AIDS
# 15   Number of deaths due to HIV/AIDS
# 16   Number of deaths due to HIV/AIDS
# 17   Number of deaths due to HIV/AIDS
# 18   Number of deaths due to HIV/AIDS
# 19   Number of deaths due to HIV/AIDS
# 20   Number of deaths due to HIV/AIDS
# 21   Number of deaths due to HIV/AIDS
# 22   Number of deaths due to HIV/AIDS
# ...

# %%
hivdeaths.drop(["GHO (CODE)", "GHO (URL)", "PUBLISHSTATE (CODE)", "PUBLISHSTATE (DISPLAY)", "YEAR (DISPLAY)", "YEAR (URL)"], axis=1, inplace=True)

# %%
hivdeaths.columns
# Out:
# Index(['GHO (DISPLAY)', 'PUBLISHSTATE (URL)', 'YEAR (CODE)', 'REGION (CODE)',
#        'REGION (DISPLAY)', 'REGION (URL)', 'COUNTRY (CODE)',
#        'COUNTRY (DISPLAY)', 'COUNTRY (URL)', 'Display Value', 'Numeric', 'Low',
#        'High', 'StdErr', 'StdDev', 'Comments'],
#       dtype='object')

# %%
hivdeaths.drop(["GHO (DISPLAY)", "PUBLISHSTATE (URL)", "REGION (URL)", "COUNTRY (URL)", "Display Value", "Low", "High", "StdErr", "StdDev", "Comments"], axis=1, inplace=True)

# %%
hivdeaths.columns
# Out:
# Index(['YEAR (CODE)', 'REGION (CODE)', 'REGION (DISPLAY)', 'COUNTRY (CODE)',
#        'COUNTRY (DISPLAY)', 'Numeric'],
#       dtype='object')

# %%
hivdeaths.head()
# Out:
#    YEAR (CODE) REGION (CODE)       REGION (DISPLAY) COUNTRY (CODE)  \
# 0         2018           EMR  Eastern Mediterranean            AFG
# 1         2018           EUR                 Europe            ALB
# 2         2018           AFR                 Africa            DZA
# 3         2018           AFR                 Africa            AGO
# 4         2018           AMR               Americas            ARG
#
#   COUNTRY (DISPLAY)  Numeric
# 0       Afghanistan    500.0
# 1           Albania      NaN
# 2           Algeria    200.0
# 3            Angola  14000.0
# 4         Argentina   1700.0

# %%
hivdeaths["REGION (CODE)"].value_counts()
# Out:
# EUR     50
# AFR     45
# AMR     29
# EMR     20
# WPR     15
# SEAR    11
# Name: REGION (CODE), dtype: int64

# %%
hivdeaths.rename(columns = {'YEAR (CODE)':'YEAR', 'REGION (CODE)':'REGION_CODE', 'REGION (DISPLAY)':'REGION_NAME', 'COUNTRY (CODE)':'iso_alpha3', 'COUNTRY (DISPLAY)':'country_name', 'Numeric':'d_total'}, inplace = True)

# %%
hivdeaths.columns
# Out:
# Index(['YEAR', 'REGION_CODE', 'REGION_NAME', 'iso_alpha3', 'country_name',
#        'd_total'],
#       dtype='object')

# %%
hivdeaths.to_csv('/Users/jbrant/Desktop/statistics/hivdeaths_trimmed.csv', index=False)

# %%
hivliving=pd.read_csv("../../../projects/hiv-statistics/resources/living_with_hiv.csv", encoding='latin-1')

# %%
hivliving.columns
# Out:
# Index(['GHO (CODE)', 'GHO (DISPLAY)', 'GHO (URL)', 'PUBLISHSTATE (CODE)',
#        'PUBLISHSTATE (DISPLAY)', 'PUBLISHSTATE (URL)', 'YEAR (CODE)',
#        'YEAR (DISPLAY)', 'YEAR (URL)', 'REGION (CODE)', 'REGION (DISPLAY)',
#        'REGION (URL)', 'COUNTRY (CODE)', 'COUNTRY (DISPLAY)', 'COUNTRY (URL)',
#        'Display Value', 'Numeric', 'Low', 'High', 'StdErr', 'StdDev',
#        'Comments'],
#       dtype='object')

# %%
hivliving.drop(["GHO (CODE)", "GHO (URL)", "PUBLISHSTATE (CODE)", "PUBLISHSTATE (DISPLAY)", "YEAR (DISPLAY)", "YEAR (URL)"], axis=1, inplace=True)

# %%
hivliving.columns
# Out:
# Index(['GHO (DISPLAY)', 'PUBLISHSTATE (URL)', 'YEAR (CODE)', 'REGION (CODE)',
#        'REGION (DISPLAY)', 'REGION (URL)', 'COUNTRY (CODE)',
#        'COUNTRY (DISPLAY)', 'COUNTRY (URL)', 'Display Value', 'Numeric', 'Low',
#        'High', 'StdErr', 'StdDev', 'Comments'],
#       dtype='object')

# %%
hivliving.rename(columns = {'YEAR (CODE)':'YEAR', 'REGION (CODE)':'REGION_CODE', 'REGION (DISPLAY)':'REGION_NAME', 'COUNTRY (CODE)':'iso_alpha3', 'COUNTRY (DISPLAY)':'country_name', 'Numeric':'l_total'}, inplace = True)

# %%
hivliving.drop(["GHO (DISPLAY)", "PUBLISHSTATE (URL)", "REGION (URL)", "COUNTRY (URL)", "Display Value", "Low", "High", "StdErr", "StdDev", "Comments"], axis=1, inplace=True)

# %%
hivliving.columns
# Out:
# Index(['YEAR', 'REGION_CODE', 'REGION_NAME', 'iso_alpha3', 'country_name',
#        'l_total'],
#       dtype='object')

# %%
hivliving.to_csv('/Users/jbrant/Desktop/statistics/hivliving_trimmed.csv', index=False)

# %%
hivnew=pd.read_csv("../../../projects/hiv-statistics/resources/new_infections.csv", encoding='latin-1')

# %%
hivnew.columns
# Out:
# Index(['GHO (CODE)', 'GHO (DISPLAY)', 'GHO (URL)', 'PUBLISHSTATE (CODE)',
#        'PUBLISHSTATE (DISPLAY)', 'PUBLISHSTATE (URL)', 'YEAR (CODE)',
#        'YEAR (DISPLAY)', 'YEAR (URL)', 'REGION (CODE)', 'REGION (DISPLAY)',
#        'REGION (URL)', 'COUNTRY (CODE)', 'COUNTRY (DISPLAY)', 'COUNTRY (URL)',
#        'Display Value', 'Numeric', 'Low', 'High', 'StdErr', 'StdDev',
#        'Comments'],
#       dtype='object')

# %%
hivnew.drop(["GHO (DISPLAY)", "PUBLISHSTATE (URL)", "REGION (URL)", "COUNTRY (URL)", "Display Value", "Low", "High", "StdErr", "StdDev", "Comments"], axis=1, inplace=True)

# %%
hivnew.drop(["GHO (CODE)", "GHO (URL)", "PUBLISHSTATE (CODE)", "PUBLISHSTATE (DISPLAY)", "YEAR (DISPLAY)", "YEAR (URL)"], axis=1, inplace=True)

# %%
hivnew.columns
# Out:
# Index(['YEAR (CODE)', 'REGION (CODE)', 'REGION (DISPLAY)', 'COUNTRY (CODE)',
#        'COUNTRY (DISPLAY)', 'Numeric'],
#       dtype='object')

# %%
hivnew.rename(columns = {'YEAR (CODE)':'YEAR', 'REGION (CODE)':'REGION_CODE', 'REGION (DISPLAY)':'REGION_NAME', 'COUNTRY (CODE)':'iso_alpha3', 'COUNTRY (DISPLAY)':'country_name', 'Numeric':'n_total'}, inplace = True)

# %%
hivnew.columns
# Out:
# Index(['YEAR', 'REGION_CODE', 'REGION_NAME', 'iso_alpha3', 'country_name',
#        'n_total'],
#       dtype='object')

# %%
hivnew.to_csv('/Users/jbrant/Desktop/statistics/newinfections_trimmed.csv', index=False)

# %%
mergepart1=pd.merge(hivnew, hivliving, left_on='iso_alpha3', right_on='iso_alpha3', how='outer')

# %%
mergepart1.head()
# Out:
#    YEAR_x REGION_CODE_x          REGION_NAME_x iso_alpha3 country_name_x  \
# 0    2018           EMR  Eastern Mediterranean        AFG    Afghanistan
# 1    2018           EUR                 Europe        ALB        Albania
# 2    2018           AFR                 Africa        DZA        Algeria
# 3    2018           AFR                 Africa        AGO         Angola
# 4    2018           AMR               Americas        ARG      Argentina
#
#    n_total  YEAR_y REGION_CODE_y          REGION_NAME_y country_name_y  \
# 0    840.0    2018           EMR  Eastern Mediterranean    Afghanistan
# 1      NaN    2018           EUR                 Europe        Albania
# 2   1300.0    2018           AFR                 Africa        Algeria
# 3  28000.0    2018           AFR                 Africa         Angola
# 4   6500.0    2018           AMR               Americas      Argentina
#
#     l_total
# 0    7200.0
# 1       NaN
# 2   16000.0
# 3  330000.0
# 4  140000.0

# %%
mergepart1.to_csv('/Users/jbrant/Desktop/statistics/combo1.csv', index=False)

# %%
mergefinal=pd.merge(mergepart1, hivdeaths, left_on='iso_alpha3', right_on='iso_alpha3', how='outer')

# %%
mergefinal.columns
# Out:
# Index(['YEAR_x', 'REGION_CODE_x', 'REGION_NAME_x', 'iso_alpha3',
#        'country_name_x', 'n_total', 'YEAR_y', 'REGION_CODE_y', 'REGION_NAME_y',
#        'country_name_y', 'l_total', 'YEAR', 'REGION_CODE', 'REGION_NAME',
#        'country_name', 'd_total'],
#       dtype='object')

# %%
mergefinal.head(20)
# Out:
#     YEAR_x REGION_CODE_x          REGION_NAME_x iso_alpha3  \
# 0     2018           EMR  Eastern Mediterranean        AFG
# 1     2018           EUR                 Europe        ALB
# 2     2018           AFR                 Africa        DZA
# 3     2018           AFR                 Africa        AGO
# 4     2018           AMR               Americas        ARG
# 5     2018           EUR                 Europe        ARM
# 6     2018           WPR        Western Pacific        AUS
# 7     2018           EUR                 Europe        AUT
# 8     2018           EUR                 Europe        AZE
# 9     2018           AMR               Americas        BHS
# 10    2018           EMR  Eastern Mediterranean        BHR
# 11    2018          SEAR        South-East Asia        BGD
# 12    2018           AMR               Americas        BRB
# 13    2018           EUR                 Europe        BLR
# 14    2018           EUR                 Europe        BEL
# ...

# %%
mergefinal.drop(["YEAR_x", "REGION_CODE_x", "REGION_NAME_x", "YEAR_y", "REGION_CODE_y", "REGION_NAME_y","country_name_x", "country_name_y"], axis=1, inplace=True)

# %%
mergefinal.head(20)
# Out:
#    iso_alpha3  n_total   l_total  YEAR REGION_CODE            REGION_NAME  \
# 0         AFG    840.0    7200.0  2018         EMR  Eastern Mediterranean
# 1         ALB      NaN       NaN  2018         EUR                 Europe
# 2         DZA   1300.0   16000.0  2018         AFR                 Africa
# 3         AGO  28000.0  330000.0  2018         AFR                 Africa
# 4         ARG   6500.0  140000.0  2018         AMR               Americas
# 5         ARM    200.0    3500.0  2018         EUR                 Europe
# 6         AUS   1000.0   28000.0  2018         WPR        Western Pacific
# 7         AUT      NaN       NaN  2018         EUR                 Europe
# 8         AZE      NaN       NaN  2018         EUR                 Europe
# 9         BHS    500.0    6000.0  2018         AMR               Americas
# 10        BHR      NaN       NaN  2018         EMR  Eastern Mediterranean
# 11        BGD   1600.0   14000.0  2018        SEAR        South-East Asia
# ...

# %%
mergefinal.to_csv('/Users/jbrant/Desktop/statistics/hiv_combined_stats_final.csv', index=False)
